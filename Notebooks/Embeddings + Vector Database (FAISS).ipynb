# %% [markdown]
# - Install dependencies

# %%
# !pip install sentence-transformers faiss-cpu
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\tina\anaconda3\lib\site-packages (5.2.2)
# Requirement already satisfied: faiss-cpu in c:\users\tina\anaconda3\lib\site-packages (1.13.2)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\users\tina\anaconda3\lib\site-packages (from sentence-transformers) (4.57.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\tina\anaconda3\lib\site-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: torch>=1.11.0 in c:\users\tina\anaconda3\lib\site-packages (from sentence-transformers) (2.9.1)
# Requirement already satisfied: numpy in c:\users\tina\anaconda3\lib\site-packages (from sentence-transformers) (2.3.5)
# Requirement already satisfied: scikit-learn in c:\users\tina\anaconda3\lib\site-packages (from sentence-transformers) (1.7.2)
# Requirement already satisfied: scipy in c:\users\tina\anaconda3\lib\site-packages (from sentence-transformers) (1.16.3)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\tina\anaconda3\lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: tqdm in c:\users\tina\anaconda3\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: filelock in c:\users\tina\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (3.20.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\tina\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\tina\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\tina\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2025.9.1)
# Requirement already satisfied: requests in c:\users\tina\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\tina\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\tina\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\tina\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.10.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\tina\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\tina\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in c:\users\tina\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\tina\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\tina\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\tina\anaconda3\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\tina\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\tina\anaconda3\lib\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tina\anaconda3\lib\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tina\anaconda3\lib\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tina\anaconda3\lib\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (2025.11.12)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\tina\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\tina\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)

# %% [markdown]
# - Load clean_parts.csv

# %%
import pandas as pd

df = pd.read_csv("clean_parts.csv")

print(df.shape)
df.head()
# Out:
# (663, 33)
#    ID                                        DESCRIPTION Attribut1  \
# 0  A1  Indicator Red Fast Movement 1.6A 250V Holder P...      Fast
# 1  A2  Non Resettable Indicators Electric Indicator, ...       NaN
# 2  A3  Indicator Red Fast Movement 8A 250V Holder Pla...      Fast
# 3  A4  Non Resettable Indicators Electric Indicator, ...       NaN
# 4  A5  Indicator Red Fast Movement 12.5A 250V Holder ...      Fast
#
#   Additional Feature                      Application Characteristic Temp  \
# 0                NaN  Primary Protection In Equipment      VERY FAST  NaN
# 1                NaN  Primary Protection In Equipment      VERY FAST  NaN
# 2                NaN  Primary Protection In Equipment      VERY FAST  NaN
# 3                NaN  Primary Protection In Equipment      VERY FAST  NaN
# 4                NaN  Primary Protection In Equipment      VERY FAST  NaN
#
#   Height Length in mm Rating  ... Physical Dimension Pre-arcing time-Min (ms)  \
# 0   20mm        5.2mm   1.6A  ...     5.2mm  x  20mm                      3ms
# 1   20mm        5.2mm    NaN  ...     5.2mm  x  20mm                      3ms
# 2   20mm        5.2mm     8A  ...     5.2mm  x  20mm                     10ms
# 3   20mm        5.2mm    NaN  ...     5.2mm  x  20mm                     10ms
# 4   20mm        5.2mm  12.5A  ...     5.2mm  x  20mm                     10ms
#
#   Product Diameter Product Length Rated Breaking Capacity (A)  \
# 0            5.2mm           20mm                       1500A
# 1            5.2mm           20mm                       1500A
# 2            5.2mm           20mm                       1500A
# 3            5.2mm           20mm                       1500A
# 4            5.2mm           20mm                        500A
#
#   Rated Current (A) Rated Voltage (V) Rated Voltage(AC) (V)  \
# 0              1.6A              250V                  250V
# 1              6.3A              250V                  250V
# 2                8A              250V                  250V
# 3               10A              250V                  250V
# 4             12.5A              250V                  250V
#
#   Rated Voltage(DC) (V)                                      combined_text
# 0                   NaN  indicator red fast movement 1 6a 250v holder p...
# 1                   NaN  non resettable indicators electric indicator v...
# 2                   NaN  indicator red fast movement 8a 250v holder pla...
# 3                   NaN  non resettable indicators electric indicator v...
# 4                   NaN  indicator red fast movement 12 5a 250v holder ...
#
# [5 rows x 33 columns]

# %% [markdown]
# - Initialize Embedding Model

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("all-MiniLM-L6-v2")

print("✅ Model loaded")
# Out:
# ✅ Model loaded

# %% [markdown]
# - Generate Embeddings

# %%
texts = df["combined_text"].tolist()

embeddings = model.encode(
    texts,
    show_progress_bar=True
)

print("Embeddings shape:", embeddings.shape)
# Out:
# Batches:   0%|          | 0/21 [00:00<?, ?it/s]
# Embeddings shape: (663, 384)

# %% [markdown]
# - Create FAISS Index

# %%
import faiss
import numpy as np

# Convert embeddings to float32 (FAISS requirement)
embeddings = np.array(embeddings).astype("float32")

dimension = embeddings.shape[1]

# Create FAISS index (L2 / cosine-style search)
index = faiss.IndexFlatL2(dimension)

# Add vectors
index.add(embeddings)

print("Total vectors in index:", index.ntotal)
# Out:
# Total vectors in index: 663

# %% [markdown]
# - Similarity Search Helper

# %%
from sentence_transformers import SentenceTransformer

def search_parts(query, top_k=5):
    # Encode query
    q_emb = model.encode([query]).astype("float32")

    # Search FAISS
    distances, indices = index.search(q_emb, top_k)

    results = df.iloc[indices[0]][["ID", "DESCRIPTION", "combined_text"]].copy()
    results["distance"] = distances[0]

    return results

# %% [markdown]
# - Example Query

# %%
query = "fast blow ceramic fuse 5x20mm 250v"

results = search_parts(query, top_k=5)
results
# Out:
#        ID                                        DESCRIPTION  \
# 204  A261  Indicator 250V 5X20 6.3A Electric Indicator, F...
# 207  A265  Indicator Red Fast Movement 0.1A 250V Axial 5 ...
# 195  A252  Indicator Red Fast Movement 1.6A 250V Axial 5 ...
# 184  A237  Indicator Red Slow Blow Movement 12A 250V Axia...
# 206  A264  Indicator Red Fast Movement 0.1A 250V Axial 5 ...
#
#                                          combined_text  distance
# 204  indicator 250v 5x20 6 3a electric indicator fa...  0.996591
# 207  indicator red fast movement 0 1a 250v axial 5 ...  1.008121
# 195  indicator red fast movement 1 6a 250v axial 5 ...  1.032024
# 184  indicator red slow blow movement 12a 250v axia...  1.048557
# 206  indicator red fast movement 0 1a 250v axial 5 ...  1.051002

# %%
# Try this -----Non Resettable Indicators Electric Indicator, Time Lag Blow, 4A, 250VAC, 150VDC, 1500A (IR), Inline/holder, 5x20mm
# The above thing is for A15. A15 and A16 are very similar. Only 4A and 5A is differeent.

# %% [markdown]
# - Save FAISS Index to Disk

# %%
import faiss
import pickle

# Save FAISS index
faiss.write_index(index, "parts_index.faiss")

# Save dataframe (ID mapping)
df.to_pickle("parts_metadata.pkl")

print("✅ FAISS index + metadata saved")
# Out:
# ✅ FAISS index + metadata saved

# %% [markdown]
# - Reload Test

# %%
# Reload index
index = faiss.read_index("parts_index.faiss")

# Reload metadata
df = pd.read_pickle("parts_metadata.pkl")

print("Reloaded vectors:", index.ntotal)
# Out:
# Reloaded vectors: 663

# %% [markdown]
# Why MiniLM (all-MiniLM-L6-v2)?
#
#
# 1. Lightweight → runs on CPU (perfect for your i5 + 8GB RAM)
#
# 2. Produces 384-dim embeddings → fast FAISS search
#
# 3. Strong semantic performance on short technical texts
#
# 4. Industry standard for retrieval tasks
#
# 5. HuggingFace benchmarked
#
# 6. Much faster than BERT / MPNet on laptops
#
# - all-MiniLM-L6-v2 was selected due to its balance between semantic accuracy and computational efficiency, making it suitable for local deployment on limited hardware while still producing high-quality embeddings for technical product descriptions.

# %% [markdown]
# - Create Ollama Helper

# %%
import subprocess

def ask_phi3(prompt):
    result = subprocess.run(
        ["ollama", "run", "phi3"],
        input=prompt.encode("utf-8"),   # <-- encode input
        capture_output=True
    )

    return result.stdout.decode("utf-8", errors="ignore")

# %% [markdown]
# - RAG Recommendation Function

# %%
def recommend_parts(query, top_k=5):
    q_emb = model.encode([query]).astype("float32")
    distances, indices = index.search(q_emb, top_k)

    retrieved = df.iloc[indices[0]][["ID", "DESCRIPTION"]].reset_index(drop=True)

    context = ""
    for i, row in retrieved.iterrows():
        context += f"{i+1}. {row['ID']} | {row['DESCRIPTION']}\n"

    prompt = f"""
You are an industrial text similarity system.

You are given EXACTLY {top_k} parts.

Rules:
- Do NOT add or remove items.
- Do NOT invent IDs.
- Do NOT rank or reject.
- Do NOT speculate.
- For each numbered item, explain in ONE short sentence how it is similar to the user input.

User input:
{query}

Parts:
{context}

Output format (must match numbering):

1. ID – similarity explanation
2. ID – similarity explanation
3. ID – similarity explanation
4. ID – similarity explanation
5. ID – similarity explanation
"""

    response = ask_phi3(prompt)

    return retrieved, response

# %% [markdown]
# - Test Full System

# %%
query = "fast blow ceramic fuse 5x20mm 250v"

matches, explanation = recommend_parts(query)

matches, explanation
# Out:
# (     ID                                        DESCRIPTION
#  0  A261  Indicator 250V 5X20 6.3A Electric Indicator, F...
#  1  A265  Indicator Red Fast Movement 0.1A 250V Axial 5 ...
#  2  A252  Indicator Red Fast Movement 1.6A 250V Axial 5 ...
#  3  A237  Indicator Red Slow Blow Movement 12A 250V Axia...
#  4  A264  Indicator Red Fast Movement 0.1A 250V Axial 5 ...,
#  '\n1. A261 - Similar to the user input due to its voltage rating of 250V, blow size indication with a fast response time (indicated by "Fast Blow"), and dimensions in 5x20mm which match exactly as specified in the user query.\n\n2. A265 - This part is similar because it also carries a voltage rating of 250V, features quick action with its red fast movement (indicated by "Fast Movement"), and has ceramic bulk construction suitable for industrial applications as implied in the user\'s description; both parts have dimensions that fit together perfectly at 5x20mm.\n\n3. A252 - It matches due to sharing a voltage rating of exactly 250V, is characterized by its red fast movement attribute (which suggests quick response time), and similar ceramic material construction like the user input; also both parts share compatible dimensions that are noted as being suitable for through-hole mounting at 5x20mm.\n\n4. A237 - The part is considered alike because it has a voltage rating of 250V and shares similar physical size with fuse dimension inputs (even though its movement speed differs, the key specifications align), although this particular one features slow blow characteristics which don\'t exactly match user input regarding response time.\n\n5. A264 - It is akin to the query because of identical voltage rating at 250V and fast indication with red in color (implying rapid operation as suggested by "Fast Movement"), while also being made from ceramic material; both share compatible through-hole mounting dimensions, even though this component has a lower current rated amperage than specified.\n\n')

# %% [markdown]
# # ✍️ Model Justification
# - Phi-3 Mini
#
# Phi-3 Mini was selected due to its lightweight footprint, strong instruction-following ability, and efficient CPU inference, making it suitable for deployment on resource-constrained systems (Intel i5, 8GB RAM). Larger models such as Llama-3 or Mistral were avoided due to higher memory requirements with limited accuracy gains for structured recommendation tasks.
#
# - MiniLM Embeddings
#
# all-MiniLM-L6-v2 was chosen for semantic embedding because of its compact 384-dimensional vectors, fast inference speed, and strong performance on sentence similarity benchmarks, making it ideal for local vector search.
